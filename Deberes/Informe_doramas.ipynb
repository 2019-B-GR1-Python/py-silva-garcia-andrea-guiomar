# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
path="C://Users//Asus//Documents//GitHub//py-silva-garcia-andrea-guiomar//Deberes//proyecto_arania//arania_dorama//arania_dorama//spiders//drama.csv"
df = pd.read_csv(
        path)

path_guardado='C://Users//Asus//Documents//GitHub//py-silva-garcia-andrea-guiomar//Deberes//proyecto_arania//arania_dorama//arania_dorama//spiders//drama.csv.pickle'
df.to_pickle(path_guardado)
df_completo_pickle = pd.read_pickle(path_guardado)

# %%
path="C://Users//Asus//Documents//GitHub//py-silva-garcia-andrea-guiomar//Deberes//proyecto_arania//arania_dorama//arania_dorama//spiders//drama2.csv"
df2 = pd.read_csv(
        path)

path_guardado='C://Users//Asus//Documents//GitHub//py-silva-garcia-andrea-guiomar//Deberes//proyecto_arania//arania_dorama//arania_dorama//spiders//drama2.csv.pickle'
df2.to_pickle(path_guardado)
df2_completo_pickle = pd.read_pickle(path_guardado)

# %%
path="C://Users//Asus//Documents//GitHub//py-silva-garcia-andrea-guiomar//Deberes//proyecto_arania//arania_dorama//arania_dorama//spiders//drama3.csv"
df3 = pd.read_csv(
        path, usecols=range(0,2))
df.columns = ['index','Titulo','Estrellas']

path_guardado='C://Users//Asus//Documents//GitHub//py-silva-garcia-andrea-guiomar//Deberes//proyecto_arania//arania_dorama//arania_dorama//spiders//drama3.csv.pickle'
df3.to_pickle(path_guardado)
df3_completo_pickle = pd.read_pickle(path_guardado)

# %%
df_completo_pickle.head()
# Out:
#                   Titulo  visitas  popularidad
# 0           My Holo Love    9.018        93.88
# 1   Crash Landing on You    6.019        92.19
# 2    Boys Before Flowers    5.355        86.68
# 3          Forest (2020)    4.281        95.89
# 4  Eternal Love of Dream    3.891        93.41

# %%
df2_completo_pickle.head()
# Out:
#                    Drama  Anio
# 0           My Holo Love  2020
# 1   Crash Landing on You  2019
# 2    Boys Before Flowers  2009
# 3          Forest (2020)  2020
# 4  Eternal Love of Dream  2020

# %%
df3_completo_pickle.head()
# Out:
#                  Titulo Estrellas
# 0          My Holo Love       4.7
# 1  Tell Me What You Saw       4.5
# 2        The Great Lord       4.7
# 3  Meteor Garden (2018)       4.7
# 4   Love of 7.7 Billion       4.7

# %%
fig = plt.figure(figsize=(30,10))


df_completo_pickle.visitas[df_completo_pickle.Titulo== "Boys Before Flowers"].value_counts(normalize = True).plot(kind='bar',alpha=0.5)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-6fd45cdeccaf> in <module>
#       2
#       3
# ----> 4 df_completo_pickle.Titulo[df_completo_pickle.visitas].value_counts(normalize = True).plot(kind='bar',alpha=0.5)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     247     def generate(self):
#     248         self._args_adjust()
# --> 249         self._compute_plot_data()
#     250         self._setup_subplots()
#     251         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     365         if is_empty:
#     366             raise TypeError('Empty {0!r}: no numeric data to '
# --> 367                             'plot'.format(numeric_data.__class__.__name__))
#     368
#     369         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
fig = plt.figure(figsize=(30,10))

df.visitas.plot(kind="bar")
plt.show()

# %%
df_completo_pickle.visitas[df_completo_pickle.Titulo=''].value_counts(normalize = True).plot(kind='bar',alpha=0.5)
# Out:
#   File "<ipython-input-103-cee7d7486399>", line 1
#     df_completo_pickle.visitas[df_completo_pickle.Titulo=''].value_counts(normalize = True).plot(kind='bar',alpha=0.5)
#                                                         ^
# SyntaxError: invalid syntax

# %%
plot = df.plot.pie( y='popularidad',figsize=(5, 5))

# %%
df2_completo_pickle.Anio.value_counts(normalize = True).plot(kind='bar',alpha=0.5)

# %%
fig = plt.figure(figsize=(30,10))


df2_completo_pickle.Drama.value_counts(normalize = True).plot(kind='pie',alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-bbc208653eb7> in <module>
#       2
#       3
# ----> 4 df2_completo_pickle.Drama.value_counts(normalize = True).plot(kind='pie',alpha=0.5)
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     249         self._compute_plot_data()
#     250         self._setup_subplots()
# --> 251         self._make_plot()
#     252         self._add_table()
#     253         self._make_legend()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _make_plot(self)
#    1537             else:
#    1538                 blabels = None
# -> 1539             results = ax.pie(y, labels=blabels, **kwds)
#    1540
#    1541             if kwds.get('autopct', None) is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: pie() got an unexpected keyword argument 'alpha'

# %%
fig = plt.figure(figsize=(30,10))

df3.Titulo.plot(kind="bar")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-b779e5363f8c> in <module>
#       1 fig = plt.figure(figsize=(30,10))
#       2
# ----> 3 df3.Titulo.plot(kind="bar")
#       4 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     247     def generate(self):
#     248         self._args_adjust()
# --> 249         self._compute_plot_data()
#     250         self._setup_subplots()
#     251         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     365         if is_empty:
#     366             raise TypeError('Empty {0!r}: no numeric data to '
# --> 367                             'plot'.format(numeric_data.__class__.__name__))
#     368
#     369         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
